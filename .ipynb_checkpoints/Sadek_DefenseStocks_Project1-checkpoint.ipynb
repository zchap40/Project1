# %%
## PERFORMANCE OF DEFENCE STOCKS DURING PERIODS OF GEOPOLITICAL TENSION ##
## Akram S. Sadek ##

# Setup Notebook

import numpy as np
import pandas as pd
import os
import datetime as dt
import pandas_datareader.data as pdr
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.style.use('ggplot')
save_results_to = '/Users/akramsadek/Desktop/NYCDSA/Homework/Project1/Presentation/Figures/'

# %%
# Date definitions

df_start = '1989-11-1'
df_end = '2022-1-30'

# Notable geopolitical events
berlin_wall = '1989-11-9'
kuwait_invasion = '1990-8-2'
iraq_war = '1991-1-16'
afghanistan_invasion = '2001-10-7'
iraq_invasion = '2003-3-20'

russia_ukraine_1_start = '2021-3-3'
russia_ukraine_1_end = '2021-4-22'

russia_china = '2021-10-11'

# Time periods for analysis

# Period A
fall_comm_start = '1989-11-9'
fall_comm_end = '1990-8-1'

# Period B
iraq_1_start = '1990-8-2'
iraq_1_end = '1991-2-28'

# Period C
afghanistan_start = '2001-9-17'
afghanistan_end = '2014-12-28'

# Period D
iraq_2_start = '2002-9-12'
iraq_2_end = '2009-4-30'

#Period E
russia_china_start = '2021-10-11'
russia_china_end = '2022-1-28'

# %%
# Main defence stocks

# Lockheed-Martin, Northrup Grumman, Raytheon Technologies, General Dynamics, BAE Systems
LMT = pdr.DataReader('LMT', 'yahoo', start = df_start, end = df_end)
NOC = pdr.DataReader('NOC', 'yahoo', start = df_start, end = df_end)
RTX = pdr.DataReader('RTX', 'yahoo', start = df_start, end = df_end)
GD = pdr.DataReader('GD', 'yahoo', start = df_start, end = df_end)
BA_L = pdr.DataReader('BA.L', 'yahoo', start = df_start, end = df_end)

# Smaller defence stocks

# L3Harris Technologies, Leidos Holdings
LHX = pdr.DataReader('LHX', 'yahoo', start = df_start, end = df_end)
LDOS = pdr.DataReader('LDOS', 'yahoo', start = df_start, end = df_end)

# Dual civilian-defence stocks

# British Aerospace, Honeywell International, Airbus, Rolls-Royce Holdings
BA = pdr.DataReader('BA', 'yahoo', start = df_start, end = df_end)
HON = pdr.DataReader('HON', 'yahoo', start = df_start, end = df_end)
AIR_DE = pdr.DataReader('AIR.DE', 'yahoo', start = df_start, end = df_end)
RRU_DE = pdr.DataReader('RRU.DE', 'yahoo', start = df_start, end = df_end)

# %%
# Tech stocks

# Tesla, Xilinx, Broadcom, GlobalFoundries, Intel, Microsoft, IBM
TSLA = pdr.DataReader('TSLA', 'yahoo', start = df_start, end = df_end)
XLNX = pdr.DataReader('XLNX', 'yahoo', start = df_start, end = df_end)
AVGO = pdr.DataReader('AVGO', 'yahoo', start = df_start, end = df_end)
GFS = pdr.DataReader('GFS', 'yahoo', start = df_start, end = df_end)
INTC = pdr.DataReader('INTC', 'yahoo', start = df_start, end = df_end)
MSFT = pdr.DataReader('MSFT', 'yahoo', start = df_start, end = df_end)
IBM = pdr.DataReader('IBM', 'yahoo', start = df_start, end = df_end)

# %%
# Dividends for all stocks

LMT_D = pdr.DataReader('LMT', 'yahoo-dividends', start = df_start, end = df_end)
NOC_D = pdr.DataReader('NOC', 'yahoo-dividends', start = df_start, end = df_end)
RTX_D = pdr.DataReader('RTX', 'yahoo-dividends', start = df_start, end = df_end)
GD_D = pdr.DataReader('GD', 'yahoo-dividends', start = df_start, end = df_end)
BA_L_D = pdr.DataReader('BA.L', 'yahoo-dividends', start = df_start, end = df_end)
LHX_D = pdr.DataReader('LHX', 'yahoo-dividends', start = df_start, end = df_end)
LDOS_D = pdr.DataReader('LDOS', 'yahoo-dividends', start = df_start, end = df_end)
BA_D = pdr.DataReader('BA', 'yahoo-dividends', start = df_start, end = df_end)
HON_D = pdr.DataReader('HON', 'yahoo-dividends', start = df_start, end = df_end)
AIR_DE_D = pdr.DataReader('AIR.DE', 'yahoo-dividends', start = df_start, end = df_end)
RRU_DE_D = pdr.DataReader('RRU.DE', 'yahoo-dividends', start = df_start, end = df_end)
TSLA_D = pdr.DataReader('TSLA', 'yahoo-dividends', start = df_start, end = df_end)
XLNX_D = pdr.DataReader('XLNX', 'yahoo-dividends', start = df_start, end = df_end)
AVGO_D = pdr.DataReader('AVGO', 'yahoo-dividends', start = df_start, end = df_end)
GFS_D = pdr.DataReader('GFS', 'yahoo-dividends', start = df_start, end = df_end)
INTC_D = pdr.DataReader('INTC', 'yahoo-dividends', start = df_start, end = df_end)
MSFT_D = pdr.DataReader('MSFT', 'yahoo-dividends', start = df_start, end = df_end)
IBM_D = pdr.DataReader('IBM', 'yahoo-dividends', start = df_start, end = df_end)

# %%
# Other financial indicators

# Gold (from 2000)
GC_F = pdr.DataReader('GC=F', 'yahoo', start = df_start, end = df_end)

# US Government 10 Year Bonds
TNX = pdr.DataReader('^TNX', 'yahoo', start = df_start, end = df_end)

# Oil (from 2000)
CL_F = pdr.DataReader('CL=F', 'yahoo', start = df_start, end = df_end)

# S&P500
GSPC = pdr.DataReader('^GSPC', 'yahoo', start = df_start, end = df_end)

# %%
GC_F.head()
# Out:
#                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2000-08-30  273.899994  273.899994  273.899994  273.899994     0.0  273.899994
# 2000-08-31  278.299988  274.799988  274.799988  278.299988     0.0  278.299988
# 2000-09-01  277.000000  277.000000  277.000000  277.000000     0.0  277.000000
# 2000-09-05  275.799988  275.799988  275.799988  275.799988     2.0  275.799988
# 2000-09-06  274.200012  274.200012  274.200012  274.200012     0.0  274.200012

# %%
LMT.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 1989-11-01  13.611963  13.420245  13.573620  13.496933  472374.0   5.595063
# 1989-11-02  13.535276  13.305215  13.535276  13.343558  219398.0   5.531485
# 1989-11-03  13.381902  13.075153  13.343558  13.075153  422496.0   5.420218
# 1989-11-06  13.151840  13.036810  13.075153  13.075153  288184.0   5.420218
# 1989-11-07  13.305215  12.998466  13.113497  13.266871  380442.0   5.499694

# %%
LMT.tail()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2022-01-24  374.540009  365.339996  369.549988  373.329987  3022300.0
# 2022-01-25  388.000000  370.779999  377.850006  387.170013  3182400.0
# 2022-01-26  393.630005  383.700012  388.000000  391.239990  3640500.0
# 2022-01-27  395.600006  384.739990  389.390015  389.079987  2566200.0
# 2022-01-28  393.329987  384.779999  389.100006  393.149994  2145100.0
#
#              Adj Close
# Date
# 2022-01-24  373.329987
# 2022-01-25  387.170013
# 2022-01-26  391.239990
# 2022-01-27  389.079987
# 2022-01-28  393.149994

# %%
LMT_D.head()
# Out:
#               action  value
# 2021-11-30  DIVIDEND    2.8
# 2021-08-31  DIVIDEND    2.6
# 2021-05-28  DIVIDEND    2.6
# 2021-02-26  DIVIDEND    2.6
# 2020-11-30  DIVIDEND    2.6

# %%
LMT_D.tail()
# Out:
#               action     value
# 1990-11-13  DIVIDEND  0.138037
# 1990-08-14  DIVIDEND  0.138037
# 1990-05-16  DIVIDEND  0.138037
# 1990-02-13  DIVIDEND  0.138037
# 1989-11-14  DIVIDEND  0.138037

# %%
# Dividend tables are sorted in descending order. 
# We need to sort them in ascending order. And set index as 'Date'.

LMT_D = LMT_D.reset_index()
NOC_D = NOC_D.reset_index()
RTX_D = RTX_D.reset_index()
GD_D = GD_D.reset_index()
BA_L_D = BA_L_D.reset_index()
LHX_D = LHX_D.reset_index()
LDOS_D = LDOS_D.reset_index()
BA_D = BA_D.reset_index()
HON_D = HON_D.reset_index()
AIR_DE_D = AIR_DE_D.reset_index()
RRU_DE_D = RRU_DE_D.reset_index()
TSLA_D = TSLA_D.reset_index()
XLNX_D = XLNX_D.reset_index()
AVGO_D = AVGO_D.reset_index()
GFS_D = GFS_D.reset_index()
INTC_D = INTC_D.reset_index()
MSFT_D = MSFT_D.reset_index()
IBM_D = IBM_D.reset_index()

# %%
LMT_D = LMT_D.rename(columns = {'index': 'Date'})
NOC_D = NOC_D.rename(columns = {'index': 'Date'})
RTX_D = RTX_D.rename(columns = {'index': 'Date'})
GD_D = GD_D.rename(columns = {'index': 'Date'})
BA_L_D = BA_L_D.rename(columns = {'index': 'Date'})
LHX_D = LHX_D.rename(columns = {'index': 'Date'})
LDOS_D = LDOS_D.rename(columns = {'index': 'Date'})
BA_D = BA_D.rename(columns = {'index': 'Date'})
HON_D = HON_D.rename(columns = {'index': 'Date'})
AIR_DE_D = AIR_DE_D.rename(columns = {'index': 'Date'})
RRU_DE_D = RRU_DE_D.rename(columns = {'index': 'Date'})
TSLA_D = TSLA_D.rename(columns = {'index': 'Date'})
XLNX_D = XLNX_D.rename(columns = {'index': 'Date'})
AVGO_D = AVGO_D.rename(columns = {'index': 'Date'})
GFS_D = GFS_D.rename(columns = {'index': 'Date'})
INTC_D = INTC_D.rename(columns = {'index': 'Date'})
MSFT_D = MSFT_D.rename(columns = {'index': 'Date'})
IBM_D = IBM_D.rename(columns = {'index': 'Date'})

# %%
LMT_D = LMT_D.set_index('Date')
NOC_D = NOC_D.set_index('Date')
RTX_D = RTX_D.set_index('Date')
GD_D = GD_D.set_index('Date')
BA_L_D = BA_L_D.set_index('Date')
LHX_D = LHX_D.set_index('Date')
LDOS_D = LDOS_D.set_index('Date')
BA_D = BA_D.set_index('Date')
HON_D = HON_D.set_index('Date')
AIR_DE_D = AIR_DE_D.set_index('Date')
RRU_DE_D = RRU_DE_D.set_index('Date')
TSLA_D = TSLA_D.set_index('Date')
XLNX_D = XLNX_D.set_index('Date')
AVGO_D = AVGO_D.set_index('Date')
GFS_D = GFS_D.set_index('Date')
INTC_D = INTC_D.set_index('Date')
MSFT_D = MSFT_D.set_index('Date')
IBM_D = IBM_D.set_index('Date')

# %%
LMT_D = LMT_D.sort_values(by = "Date")
NOC_D = NOC_D.sort_values(by = "Date")
RTX_D = RTX_D.sort_values(by = "Date")
GD_D = GD_D.sort_values(by = "Date")
BA_L_D = BA_L_D.sort_values(by = "Date")
LHX_D = LHX_D.sort_values(by = "Date")
LDOS_D = LDOS_D.sort_values(by = "Date")
BA_D = BA_D.sort_values(by = "Date")
HON_D = HON_D.sort_values(by = "Date")
AIR_DE_D = AIR_DE_D.sort_values(by = "Date")
RRU_DE_D = RRU_DE_D.sort_values(by = "Date")
TSLA_D = TSLA_D.sort_values(by = "Date")
XLNX_D = XLNX_D.sort_values(by = "Date")
AVGO_D = AVGO_D.sort_values(by = "Date")
GFS_D = GFS_D.sort_values(by = "Date")
INTC_D = INTC_D.sort_values(by = "Date")
MSFT_D = MSFT_D.sort_values(by = "Date")
IBM_D = IBM_D.sort_values(by = "Date")

# %%
LMT_D.head()
# Out:
#               action     value
# Date
# 1989-11-14  DIVIDEND  0.138037
# 1990-02-13  DIVIDEND  0.138037
# 1990-05-16  DIVIDEND  0.138037
# 1990-08-14  DIVIDEND  0.138037
# 1990-11-13  DIVIDEND  0.138037

# %%
LMT['Adj Close'].plot(label='Lockheed Martin', figsize=(16,5))
NOC['Adj Close'].plot(label='Northrup Grumman')
RTX['Adj Close'].plot(label='Raytheon')
GD['Adj Close'].plot(label='General Dynamics')
INTC['Adj Close'].plot(label='Intel', linestyle=':')
MSFT['Adj Close'].plot(label='Microsoft', linestyle=':')
IBM['Adj Close'].plot(label='IBM', linestyle=':')


plt.legend(prop={'size': 12})
plt.title('Defence Stocks vs Tech Stocks', fontweight = 'bold', size = 16)
plt.xticks(fontweight='bold', size=12)
plt.yticks(fontweight='bold', size=12)
plt.ylabel('Price (USD)', fontweight = 'bold', size=14)
plt.xlabel('Date', fontweight = 'bold', size=14)
plt.savefig(save_results_to + 'Fig1.png', bbox_inches='tight', format="png", dpi=600)
plt.show;

# %%
# Let's try and zoom into the earlier data to see the trend more clearly

LMT['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='Lockheed Martin', figsize=(16,5))
NOC['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='Northrup Grumman')
RTX['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='Raytheon')
GD['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='General Dynamics')
INTC['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='Intel', linestyle=':')
MSFT['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='Microsoft', linestyle=':')
IBM['Adj Close'].loc['1989-01-01':'2009-04-01'].plot(label='IBM', linestyle=':')
plt.legend(prop={'size': 12})
plt.title('Defence Stocks vs Tech Stocks', fontweight = 'bold', size = 16)
plt.xticks(fontweight='bold', size=12)
plt.yticks(fontweight='bold', size=12)
plt.ylabel('Price (USD)', fontweight = 'bold', size=14)
plt.xlabel('Date', fontweight = 'bold', size=14)
plt.savefig(save_results_to + 'Fig2.png', bbox_inches='tight', format="png", dpi=600)
plt.show;

# %%
# Concatenation of stock data in one DataFrame

stock_data = pd.concat([LMT['Adj Close'], NOC['Adj Close'], RTX['Adj Close'], GD['Adj Close'], \
                       BA_L['Adj Close'], LHX['Adj Close'], LDOS['Adj Close'], BA['Adj Close'], \
                       HON['Adj Close'], AIR_DE['Adj Close'], RRU_DE['Adj Close'], TSLA['Adj Close'], \
                       XLNX['Adj Close'], AVGO['Adj Close'], GFS['Adj Close'], INTC['Adj Close'], \
                       MSFT['Adj Close'], IBM['Adj Close'], GC_F['Adj Close'], TNX['Adj Close'], \
                       CL_F['Adj Close'], GSPC['Adj Close']], axis=1)

# %%
stock_data.columns = ['LMT', 'NOC', 'RTX', 'GD', 'BA_L', 'LHX', 'LDOS', 'BA', 'HON', 'AIR_DE', \
                      'RRU_DE', 'TSLA', 'XLNX', 'AVGO', 'GFS', 'INTC', 'MSFT', 'IBM', 'Gold', \
                      'Bonds', 'Oil', 'S&P500']

# %%
# Make sure date index is a datetime series

stock_data = stock_data.reset_index()
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data = stock_data.set_index('Date')

# %%
stock_data.head()
# Out:
#                  LMT       NOC       RTX        GD       BA_L       LHX  LDOS  \
# Date
# 1989-11-01  5.595063  3.736066  2.046658  2.309851  46.585613  3.809030   NaN
# 1989-11-02  5.531485  3.688170  2.046658  2.277165  45.393291  3.732081   NaN
# 1989-11-03  5.420218  3.616323  2.041864  2.298957  46.074608  3.719256   NaN
# 1989-11-06  5.420218  3.448677  2.003519  2.271717  45.478424  3.578181   NaN
# 1989-11-07  5.499694  3.520524  2.013107  2.277165  46.074608  3.539707   NaN
#
#                    BA       HON  AIR_DE  ...  XLNX  AVGO  GFS      INTC  \
# Date                                     ...
# 1989-11-01  10.024436  4.116004     NaN  ...   NaN   NaN  NaN  0.624656
# 1989-11-02  10.069100  4.116004     NaN  ...   NaN   NaN  NaN  0.591779
# 1989-11-03  10.136072  4.144487     NaN  ...   NaN   NaN  NaN  0.575340
# 1989-11-06   9.734204  4.116004     NaN  ...   NaN   NaN  NaN  0.558903
# 1989-11-07   9.577918  4.087517     NaN  ...   NaN   NaN  NaN  0.591779
#
#                 MSFT        IBM  Gold  Bonds  Oil      S&P500
# Date
# 1989-11-01  0.360051  11.256062   NaN   7.91  NaN  341.200012
# 1989-11-02  0.334294  11.151810   NaN   7.87  NaN  338.480011
# 1989-11-03  0.343062  11.223026   NaN   7.96  NaN  337.619995
# 1989-11-06  0.338678  11.009385   NaN   8.00  NaN  332.609985
# 1989-11-07  0.355118  11.094839   NaN   7.90  NaN  334.809998
#
# [5 rows x 22 columns]

# %%
# We want to make five different versions of the DataFrame corresponding to different geopolitical events

stock_data_A = stock_data.loc[fall_comm_start:fall_comm_end]
stock_data_B = stock_data.loc[iraq_1_start:iraq_1_end]
stock_data_C = stock_data.loc[afghanistan_start:afghanistan_end]
stock_data_D = stock_data.loc[iraq_2_start:iraq_2_end]
stock_data_E = stock_data.loc[russia_china_start:russia_china_end]

# %%
# Setting globally not to limit showing columns during head/tail
pd.options.display.max_columns = None

stock_data_A.head()
# Out:
#                  LMT       NOC       RTX        GD       BA_L       LHX  LDOS  \
# Date
# 1989-11-09  5.626856  3.592372  2.041864  2.277165  46.755913  3.591006   NaN
# 1989-11-10  5.658642  3.592372  2.085002  2.266269  45.563641  3.642306   NaN
# 1989-11-13  5.626856  3.592372  2.089795  2.239030  44.711964  3.693606   NaN
# 1989-11-14  5.379554  3.544472  2.061037  2.222687  44.797131  3.667955   NaN
# 1989-11-15  5.299265  3.568422  2.089795  2.206343  44.200970  3.705659   NaN
#
#                    BA       HON  AIR_DE  RRU_DE  TSLA  XLNX  AVGO  GFS  \
# Date
# 1989-11-09   9.890486  4.158728     NaN     NaN   NaN   NaN   NaN  NaN
# 1989-11-10  10.002116  4.172971     NaN     NaN   NaN   NaN   NaN  NaN
# 1989-11-13  10.033539  4.196043     NaN     NaN   NaN   NaN   NaN  NaN
# 1989-11-14   9.943753  4.095106     NaN     NaN   NaN   NaN   NaN  NaN
# 1989-11-15  10.078432  4.095106     NaN     NaN   NaN   NaN   NaN  NaN
#
#                 INTC      MSFT        IBM  Gold  Bonds  Oil      S&P500
# Date
# 1989-11-09  0.605869  0.367175  11.094839   NaN   7.90  NaN  336.570007
# 1989-11-10  0.617611  0.370463  11.180294   NaN   7.92  NaN  339.100006
# 1989-11-13  0.622307  0.386356  11.194532   NaN   7.89  NaN  339.549988
# 1989-11-14  0.619959  0.379231  11.166051   NaN   7.87  NaN  337.989990
# 1989-11-15  0.634049  0.388000  11.151810   NaN   7.82  NaN  340.540009

# %%
# We need to delete columns of companies that didn't exist in the time period, or for which data is unavailable

stock_data_A = stock_data_A.drop(columns=['LDOS','AIR_DE','RRU_DE','TSLA','XLNX','AVGO','GFS','Gold','Oil'])

# %%
stock_data_A.head()
# Out:
#                  LMT       NOC       RTX        GD       BA_L       LHX  \
# Date
# 1989-11-09  5.626856  3.592372  2.041864  2.277165  46.755913  3.591006
# 1989-11-10  5.658642  3.592372  2.085002  2.266269  45.563641  3.642306
# 1989-11-13  5.626856  3.592372  2.089795  2.239030  44.711964  3.693606
# 1989-11-14  5.379554  3.544472  2.061037  2.222687  44.797131  3.667955
# 1989-11-15  5.299265  3.568422  2.089795  2.206343  44.200970  3.705659
#
#                    BA       HON      INTC      MSFT        IBM  Bonds  \
# Date
# 1989-11-09   9.890486  4.158728  0.605869  0.367175  11.094839   7.90
# 1989-11-10  10.002116  4.172971  0.617611  0.370463  11.180294   7.92
# 1989-11-13  10.033539  4.196043  0.622307  0.386356  11.194532   7.89
# 1989-11-14   9.943753  4.095106  0.619959  0.379231  11.166051   7.87
# 1989-11-15  10.078432  4.095106  0.634049  0.388000  11.151810   7.82
#
#                 S&P500
# Date
# 1989-11-09  336.570007
# 1989-11-10  339.100006
# 1989-11-13  339.549988
# 1989-11-14  337.989990
# 1989-11-15  340.540009

# %%
axes_A = pd.plotting.scatter_matrix(stock_data_A, alpha=0.2, figsize=(16,5))

for ax in axes_A.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.xaxis.label.set_size(12)
    ax.xaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_size(12)
    ax.yaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_ha('right')

for i in range(np.shape(axes_A)[0]):
    for j in range(np.shape(axes_A)[1]):
        if i < j:
            axes_A[i,j].set_visible(False)

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Fall of Communism 1989-90', y=1.075, size=20, fontweight = 'bold')
plt.savefig(save_results_to + 'Fig3.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
stock_data_B.head()
# Out:
#                  LMT       NOC       RTX        GD       BA_L       LHX  LDOS  \
# Date
# 1990-08-02  3.691762  2.952247  2.233928  1.255884  48.033428  3.120066   NaN
# 1990-08-03  3.741208  3.053180  2.204470  1.289226  49.310894  2.936531   NaN
# 1990-08-06  3.741208  3.103645  2.145553  1.333682  47.692776  2.831655   NaN
# 1990-08-07  3.790649  3.103645  2.037540  1.322568  46.841103  2.897205   NaN
# 1990-08-08  3.988421  3.078410  2.086636  1.272555  46.330135  2.831655   NaN
#
#                    BA       HON  AIR_DE  RRU_DE  TSLA      XLNX  AVGO  GFS  \
# Date
# 1990-08-02  14.550194  3.903888     NaN     NaN   NaN  0.809166   NaN  NaN
# 1990-08-03  14.686172  3.948252     NaN     NaN   NaN  0.785260   NaN  NaN
# 1990-08-06  13.734282  3.741225     NaN     NaN   NaN  0.735606   NaN  NaN
# 1990-08-07  14.142236  3.726438     NaN     NaN   NaN  0.779743   NaN  NaN
# 1990-08-08  14.414204  3.859525     NaN     NaN   NaN  0.838591   NaN  NaN
#
#                 INTC      MSFT        IBM  Gold  Bonds  Oil      S&P500
# Date
# 1990-08-02  0.756162  0.578712  12.802356   NaN   8.41  NaN  351.480011
# 1990-08-03  0.737375  0.554598  12.612792   NaN   8.43  NaN  344.859985
# 1990-08-06  0.699802  0.530486  12.254176   NaN   8.71  NaN  334.429993
# 1990-08-07  0.711544  0.537062  12.150941   NaN   8.78  NaN  334.829987
# 1990-08-08  0.697453  0.556790  12.165689   NaN   8.77  NaN  338.350006

# %%
stock_data_B = stock_data_B.drop(columns=['LDOS','AIR_DE','RRU_DE','TSLA','XLNX','AVGO','GFS','Gold','Oil'])

# %%
axes_B = pd.plotting.scatter_matrix(stock_data_B, alpha=0.2, figsize=(16,5), color='royalblue')

for ax in axes_B.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.xaxis.label.set_size(12)
    ax.xaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_size(12)
    ax.yaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_ha('right')

for i in range(np.shape(axes_B)[0]):
    for j in range(np.shape(axes_B)[1]):
        if i < j:
            axes_B[i,j].set_visible(False)
    
plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Operation Desert Storm - 1990-91', y=1.075, size=20, fontweight = 'bold')
plt.savefig(save_results_to + 'Fig4.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
stock_data_C.head()
# Out:
#                   LMT        NOC       RTX         GD        BA_L       LHX  \
# Date
# 2001-09-17  25.981411  27.765003  9.957644  27.040461  145.826675  9.833686
# 2001-09-18  26.365662  27.750355  9.992264  26.893660  143.904205  9.468014
# 2001-09-19  25.372522  28.409328  9.703105  27.004578  130.078232  9.540489
# 2001-09-20  25.100590  29.847363  8.479271  25.885769  124.760559  9.817218
# 2001-09-21  24.946892  29.097591  8.603490  27.405775  122.715286  9.586609
#
#                    BA        HON    AIR_DE       INTC       MSFT        Gold  \
# Date
# 2001-09-17  23.593908  17.617033  7.847481  14.493448  16.701622  289.799988
# 2001-09-18  21.840839  17.025816  6.568633  14.419727  17.146690  288.100006
# 2001-09-19  21.491547  15.873248  6.103596  13.688601  17.004648  291.500000
# 2001-09-20  19.613260  14.087653  6.062906  12.699432  16.022945  289.000000
# 2001-09-21  19.837337  14.810250  5.667626  11.857722  15.691501  291.899994
#
#             Bonds        Oil       S&P500
# Date
# 2001-09-17  4.611  28.809999  1038.770020
# 2001-09-18  4.705  27.700001  1032.739990
# 2001-09-19  4.681  26.719999  1016.099976
# 2001-09-20  4.728  26.590000   984.539978
# 2001-09-21  4.689  25.969999   965.799988

# %%
stock_data_C = stock_data_C.drop(columns=['LDOS','RRU_DE','TSLA','AVGO','GFS','IBM','XLNX'])

# %%
axes_C = pd.plotting.scatter_matrix(stock_data_C, alpha=0.2, figsize=(16,5), color='lightseagreen')

for ax in axes_C.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.xaxis.label.set_size(12)
    ax.xaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_size(12)
    ax.yaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_ha('right')

for i in range(np.shape(axes_C)[0]):
    for j in range(np.shape(axes_C)[1]):
        if i < j:
            axes_C[i,j].set_visible(False)

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Invasion of Afghanistan - 2001-14', y=1.075, size=20, fontweight = 'bold')
plt.savefig(save_results_to + 'Fig5.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
stock_data_D.head()
# Out:
#                   LMT        NOC        RTX         GD       BA_L        LHX  \
# Date
# 2002-09-12  39.313377  37.680416  12.629153  27.427492  97.422066  10.800601
# 2002-09-13  39.164398  37.442692  11.988394  27.430805  99.521675  10.863624
# 2002-09-16  39.176327  38.037025  12.360456  28.613684  98.597870  10.860305
# 2002-09-17  38.145531  36.699772  12.019400  27.325058  91.543152  10.730935
# 2002-09-18  38.842651  37.077164  11.905723  27.724880  84.404488  10.641376
#
#             LDOS         BA        HON    AIR_DE  RRU_DE  TSLA       XLNX  \
# Date
# 2002-09-12   NaN  24.447788  17.306345  7.893118     NaN   NaN  13.000808
# 2002-09-13   NaN  23.864258  14.387351  7.789101     NaN   NaN  12.781895
# 2002-09-16   NaN  24.970953  15.052983  7.831932     NaN   NaN  12.111017
# 2002-09-17   NaN  24.340485  14.985812  7.464812     NaN   NaN  12.160452
# 2002-09-18   NaN  24.662416  14.656044  6.944721     NaN   NaN  11.397775
#
#             AVGO  GFS      INTC       MSFT        IBM        Gold  Bonds  \
# Date
# 2002-09-12   NaN  NaN  9.677463  14.883406  42.287247  318.899994  3.967
# 2002-09-13   NaN  NaN  9.880877  15.123313  42.657944  316.600006  3.900
# 2002-09-16   NaN  NaN  9.677463  15.082275  42.552021  317.100006  3.874
# 2002-09-17   NaN  NaN  9.597333  14.927594  42.216629  317.000000  3.863
# 2002-09-18   NaN  NaN  9.418578  15.072805  40.922180  320.600006  3.849
#
#                   Oil      S&P500
# Date
# 2002-09-12  28.850000  886.909973
# 2002-09-13  29.809999  889.809998
# 2002-09-16  29.670000  891.099976
# 2002-09-17  29.080000  873.520020
# 2002-09-18  29.480000  869.460022

# %%
stock_data_D = stock_data_D.drop(columns=['LDOS','RRU_DE','TSLA','AVGO','GFS','IBM','XLNX'])

# %%
axes_D = pd.plotting.scatter_matrix(stock_data_D, alpha=0.2, figsize=(16,5), color='sandybrown')

for ax in axes_D.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.xaxis.label.set_size(12)
    ax.xaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_size(12)
    ax.yaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_ha('right')

for i in range(np.shape(axes_D)[0]):
    for j in range(np.shape(axes_D)[1]):
        if i < j:
            axes_D[i,j].set_visible(False)

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Invasion of Iraq - 2002-09', y=1.075, size=20, fontweight = 'bold')
plt.savefig(save_results_to + 'Fig6.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
stock_data_E.head()
# Out:
#                    LMT         NOC        RTX          GD        BA_L  \
# Date
# 2021-10-11  354.149933  391.451874  89.365768  201.740829  576.069397
# 2021-10-12  355.181396  388.375305  89.196762  202.407059  581.576416
# 2021-10-13  358.791565  387.011261  89.156998  202.247955  582.756470
# 2021-10-14  359.098999  388.245880  88.649971  203.988129  587.083374
# 2021-10-15  362.619873  393.642303  90.389763  206.891724  589.443542
#
#                    LHX       LDOS          BA         HON      AIR_DE  RRU_DE  \
# Date
# 2021-10-11  234.284607  97.297714  226.449997  214.363602  113.900002  1.7100
# 2021-10-12  236.026535  97.865425  223.570007  213.407745  113.120003  1.7050
# 2021-10-13  233.498245  97.825584  221.779999  214.652359  111.959999  1.6850
# 2021-10-14  235.578613  99.080528  217.440002  217.649414  113.260002  1.7074
# 2021-10-15  237.967545  99.887276  217.039993  219.770248  114.900002  1.7250
#
#                   TSLA        XLNX        AVGO  GFS       INTC        MSFT  \
# Date
# 2021-10-11  791.940002  154.910187  489.210541  NaN  53.070934  293.692688
# 2021-10-12  805.719971  155.618866  482.195404  NaN  51.809704  292.345154
# 2021-10-13  811.080017  161.348129  481.927155  NaN  51.899082  295.768890
# 2021-10-14  818.320007  165.500366  494.437103  NaN  53.527760  302.197113
# 2021-10-15  843.030029  166.837860  500.051178  NaN  54.083889  303.654449
#
#                    IBM         Gold  Bonds        Oil       S&P500
# Date
# 2021-10-11  134.373245  1754.599976  1.614  80.519997  4361.189941
# 2021-10-12  132.524109  1758.300049  1.580  80.639999  4350.649902
# 2021-10-13  132.797714  1793.699951  1.549  80.440002  4363.799805
# 2021-10-14  135.278946  1796.699951  1.519  81.309998  4438.259766
# 2021-10-15  136.429932  1767.199951  1.576  82.279999  4471.370117

# %%
stock_data_E = stock_data_E.drop(columns=['LDOS','AIR_DE','RRU_DE','GFS','IBM','HON','LHX'])

# %%
axes_E = pd.plotting.scatter_matrix(stock_data_E, alpha=0.2, figsize=(16,5), color='mediumorchid')

for ax in axes_E.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.xaxis.label.set_size(12)
    ax.xaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_size(12)
    ax.yaxis.label.set_fontweight('bold')
    ax.yaxis.label.set_ha('right')

for i in range(np.shape(axes_E)[0]):
    for j in range(np.shape(axes_E)[1]):
        if i < j:
            axes_E[i,j].set_visible(False)

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Russia/China Tension - Oct 2021-present', y=1.075, size=20, fontweight = 'bold')
plt.savefig(save_results_to + 'Fig7.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
# Plot of defence stocks vs tech stocks in the last few months

stock_data_E['LMT'].plot(label='Lockheed Martin', figsize=(16,5))
stock_data_E['NOC'].plot(label='Northrup Grumman')
#stock_data_E['RTX'].plot(label='Raytheon')
#stock_data_E['GD'].plot(label='General Dynamics')
#stock_data_E['INTC'].plot(label='Intel')
#stock_data_E['MSFT'].plot(label='Microsoft')
#stock_data_E['TSLA'].plot(label='Tesla')
stock_data_E['XLNX'].plot(label='Xilinx')
stock_data_E['AVGO'].plot(label='Broadcom')
#stock_data_E['Oil'].plot(label='Oil')
plt.legend()
plt.title('Defence Stock Performance - Russia/China Tension')
plt.ylabel('Price (USD)')
plt.savefig(save_results_to + 'Fig8.png', bbox_inches='tight', format="png", dpi=600)
plt.show;

# %%
# Setting up correlation analysis using the rate of return to construct a heat map
# Might be better than a straightforward scatter matrix

stock_return_A = stock_data_A.pct_change()
stock_corr_A = stock_return_A.corr()

stock_return_B = stock_data_B.pct_change()
stock_corr_B = stock_return_B.corr()

stock_return_C = stock_data_C.pct_change()
stock_corr_C = stock_return_C.corr()

stock_return_D = stock_data_D.pct_change()
stock_corr_D = stock_return_D.corr()

stock_return_E = stock_data_E.pct_change()
stock_corr_E = stock_return_E.corr()

# %%
stock_corr_A.head()
# Out:
#            LMT       NOC       RTX        GD      BA_L       LHX        BA  \
# LMT   1.000000  0.182408  0.385333  0.403466  0.119703  0.272825  0.091629
# NOC   0.182408  1.000000  0.217281  0.442448  0.077426  0.185101  0.182558
# RTX   0.385333  0.217281  1.000000  0.349608  0.232199  0.447899  0.331690
# GD    0.403466  0.442448  0.349608  1.000000  0.141316  0.255440  0.168614
# BA_L  0.119703  0.077426  0.232199  0.141316  1.000000  0.024461  0.062918
#
#            HON      INTC      MSFT       IBM     Bonds    S&P500
# LMT   0.263624  0.270102  0.142015  0.252746 -0.109237  0.398766
# NOC   0.223928  0.140954  0.088078  0.205072 -0.023816  0.341154
# RTX   0.293800  0.305143  0.137903  0.323868 -0.200052  0.553992
# GD    0.237830  0.142419  0.084149  0.232665  0.038300  0.377139
# BA_L  0.130689 -0.043296 -0.115566 -0.030556 -0.214769  0.101610

# %%
caxes_A = pd.plotting.scatter_matrix(stock_corr_A, diagonal = 'kde', alpha=0.2, figsize=(16,5))

for cax in caxes_A.flatten():
    cax.xaxis.label.set_rotation(90)
    cax.yaxis.label.set_rotation(0)
    cax.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Fall of Communism 1989-90', y=1.075, size='xx-large')
plt.savefig(save_results_to + 'Fig9.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
plt.imshow(stock_corr_A, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_A)), stock_corr_A.columns, rotation = 90, fontweight='bold');
plt.yticks(range(len(stock_corr_A)), stock_corr_A.columns, fontweight='bold');
plt.suptitle('Fall of Communism 1989-90', y=0.97, size='x-large', fontweight = 'bold');
plt.savefig(save_results_to + 'Fig10.png', bbox_inches='tight', format="png", dpi=600)

# %%
caxes_B = pd.plotting.scatter_matrix(stock_corr_B, diagonal = 'kde', alpha=0.2, figsize=(16,5), color = 'royalblue')

for cax in caxes_B.flatten():
    cax.xaxis.label.set_rotation(90)
    cax.yaxis.label.set_rotation(0)
    cax.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Operation Desert Storm - 1990-91', y=1.075, size='xx-large')
plt.savefig(save_results_to + 'Fig11.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
plt.imshow(stock_corr_B, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_B)), stock_corr_B.columns, rotation = 90, fontweight='bold');
plt.yticks(range(len(stock_corr_B)), stock_corr_B.columns, fontweight='bold');
plt.suptitle('Operation Desert Storm - 1990-91', y=0.97, size='x-large', fontweight = 'bold');
plt.savefig(save_results_to + 'Fig12.png', bbox_inches='tight', format="png", dpi=600)

# %%
caxes_C = pd.plotting.scatter_matrix(stock_corr_C, diagonal = 'kde', alpha=0.2, figsize=(16,5), color = 'lightseagreen')

for cax in caxes_C.flatten():
    cax.xaxis.label.set_rotation(90)
    cax.yaxis.label.set_rotation(0)
    cax.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Invasion of Afghanistan - 2001-14', y=1.075, size='xx-large')
plt.savefig(save_results_to + 'Fig13.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
plt.imshow(stock_corr_C, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_C)), stock_corr_C.columns, rotation = 90, fontweight='bold');
plt.yticks(range(len(stock_corr_C)), stock_corr_C.columns, fontweight='bold');
plt.suptitle('Invasion of Afghanistan - 2001-14', y=0.97, size='x-large', fontweight = 'bold');
plt.savefig(save_results_to + 'Fig14.png', bbox_inches='tight', format="png", dpi=600)

# %%
caxes_D = pd.plotting.scatter_matrix(stock_corr_D, diagonal = 'kde', alpha=0.2, figsize=(16,5), color = 'sandybrown')

for cax in caxes_D.flatten():
    cax.xaxis.label.set_rotation(90)
    cax.yaxis.label.set_rotation(0)
    cax.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Invasion of Iraq - 2002-09', y=1.075, size='xx-large')
plt.savefig(save_results_to + 'Fig15.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
plt.imshow(stock_corr_D, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_D)), stock_corr_D.columns, rotation = 90, fontweight='bold');
plt.yticks(range(len(stock_corr_D)), stock_corr_D.columns, fontweight='bold');
plt.suptitle('Invasion of Iraq - 2002-09', y=0.97, size='x-large', fontweight='bold');
plt.savefig(save_results_to + 'Fig16.png', bbox_inches='tight', format="png", dpi=600)

# %%
caxes_E = pd.plotting.scatter_matrix(stock_corr_E, diagonal = 'kde', alpha=0.2, figsize=(16,5), color = 'mediumorchid')

for cax in caxes_E.flatten():
    cax.xaxis.label.set_rotation(90)
    cax.yaxis.label.set_rotation(0)
    cax.yaxis.label.set_ha('right')

plt.tight_layout()
plt.gcf().subplots_adjust(wspace=0, hspace=0)
plt.suptitle('Russia/China Tension - Oct 2021-present', y=1.075, size='xx-large')
plt.savefig(save_results_to + 'Fig17.png', bbox_inches='tight', format="png", dpi=600)
plt.show();

# %%
plt.imshow(stock_corr_E, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_E)), stock_corr_E.columns, rotation = 90, fontweight='bold');
plt.yticks(range(len(stock_corr_E)), stock_corr_E.columns, fontweight='bold');
plt.suptitle('Russia/China Tension - Oct 2021-present', y=0.97, size='x-large', fontweight='bold');
plt.savefig(save_results_to + 'Fig18.png', bbox_inches='tight', format="png", dpi=600)

# %%
# Calculating the returns of each of the stocks so we can directly visualise their volatility

LMT['Returns'] = (LMT['Adj Close']/(LMT['Adj Close'].shift(1))) - 1
NOC['Returns'] = (NOC['Adj Close']/(NOC['Adj Close'].shift(1))) - 1
RTX['Returns'] = (RTX['Adj Close']/(RTX['Adj Close'].shift(1))) - 1
GD['Returns'] = (GD['Adj Close']/(GD['Adj Close'].shift(1))) - 1
BA_L['Returns'] = (BA_L['Adj Close']/(BA_L['Adj Close'].shift(1))) - 1
LHX['Returns'] = (LHX['Adj Close']/(LHX['Adj Close'].shift(1))) - 1
LDOS['Returns'] = (LDOS['Adj Close']/(LDOS['Adj Close'].shift(1))) - 1
BA['Returns'] = (BA['Adj Close']/(BA['Adj Close'].shift(1))) - 1
HON['Returns'] = (HON['Adj Close']/(HON['Adj Close'].shift(1))) - 1
AIR_DE['Returns'] = (AIR_DE['Adj Close']/(AIR_DE['Adj Close'].shift(1))) - 1
RRU_DE['Returns'] = (RRU_DE['Adj Close']/(RRU_DE['Adj Close'].shift(1))) - 1
TSLA['Returns'] = (TSLA['Adj Close']/(TSLA['Adj Close'].shift(1))) - 1
XLNX['Returns'] = (XLNX['Adj Close']/(XLNX['Adj Close'].shift(1))) - 1
AVGO['Returns'] = (AVGO['Adj Close']/(AVGO['Adj Close'].shift(1))) - 1
GFS['Returns'] = (GFS['Adj Close']/(GFS['Adj Close'].shift(1))) - 1
INTC['Returns'] = (INTC['Adj Close']/(INTC['Adj Close'].shift(1))) - 1
MSFT['Returns'] = (MSFT['Adj Close']/(MSFT['Adj Close'].shift(1))) - 1
IBM['Returns'] = (IBM['Adj Close']/(IBM['Adj Close'].shift(1))) - 1
GC_F['Returns'] = (GC_F['Adj Close']/(GC_F['Adj Close'].shift(1))) - 1
CL_F['Returns'] = (CL_F['Adj Close']/(CL_F['Adj Close'].shift(1))) - 1
GSPC['Returns'] = (GSPC['Adj Close']/(GSPC['Adj Close'].shift(1))) - 1

# %%
# Plot KDE for Period A

LMT['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='Lockheed-Martin', figsize=(10,5))
NOC['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='Northrup Grumman')
RTX['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='Raytheon')
GD['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='General Dynamics')
BA_L['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='BAE Systems')
INTC['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='Intel', linestyle='--')
MSFT['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='Microsoft', linestyle='--')
IBM['Returns'].loc[fall_comm_start:fall_comm_end].plot(kind='kde', label='IBM', linestyle='--')

plt.legend()
plt.xlim([-0.15, 0.15])
plt.ylabel('Density', fontweight='bold')
plt.yticks(fontweight='bold')
plt.xticks(fontweight='bold')
plt.suptitle('Fall of Communism 1989-90', y=0.95, size='x-large', fontweight='bold');
plt.savefig(save_results_to + 'Fig19.png', bbox_inches='tight', format="png", dpi=600)

# %%
# Plot KDE for Period B

LMT['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='Lockheed-Martin', figsize=(10,5))
NOC['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='Northrup Grumman')
RTX['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='Raytheon')
GD['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='General Dynamics')
BA_L['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='BAE Systems')
INTC['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='Intel', linestyle='--')
MSFT['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='Microsoft', linestyle='--')
IBM['Returns'].loc[iraq_1_start:iraq_1_end].plot(kind='kde', label='IBM', linestyle='--')

plt.legend()
plt.xlim([-0.15, 0.15])
plt.ylabel('Density', fontweight='bold')
plt.yticks(fontweight='bold')
plt.xticks(fontweight='bold')
plt.suptitle('Operation Desert Storm - 1990-91', y=0.95, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig20.png', bbox_inches='tight', format="png", dpi=600)

# %%
# Plot KDE for Period C

LMT['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='Lockheed-Martin', figsize=(10,5))
NOC['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='Northrup Grumman')
RTX['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='Raytheon')
GD['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='General Dynamics')
BA_L['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='BAE Systems')
INTC['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='Intel', linestyle='--')
MSFT['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='Microsoft', linestyle='--')
IBM['Returns'].loc[afghanistan_start:afghanistan_end].plot(kind='kde', label='IBM', linestyle='--')

plt.legend()
plt.xlim([-0.15, 0.15])
plt.ylabel('Density', fontweight='bold')
plt.yticks(fontweight='bold')
plt.xticks(fontweight='bold')
plt.suptitle('Invasion of Afghanistan - 2001-14', y=0.95, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig21.png', bbox_inches='tight', format="png", dpi=600)

# %%
# Plot KDE for Period D

LMT['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='Lockheed-Martin', figsize=(10,5))
NOC['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='Northrup Grumman')
RTX['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='Raytheon')
GD['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='General Dynamics')
BA_L['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='BAE Systems')
INTC['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='Intel', linestyle='--')
MSFT['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='Microsoft', linestyle='--')
IBM['Returns'].loc[iraq_2_start:iraq_2_end].plot(kind='kde', label='IBM', linestyle='--')

plt.legend()
plt.xlim([-0.15, 0.15])
plt.ylabel('Density', fontweight='bold')
plt.yticks(fontweight='bold')
plt.xticks(fontweight='bold')
plt.suptitle('Invasion of Iraq - 2002-09', y=0.95, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig22.png', bbox_inches='tight', format="png", dpi=600)

# %%
# Plot KDE for Period E

LMT['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Lockheed-Martin', figsize=(10,5))
NOC['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Northrup Grumman')
RTX['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Raytheon')
GD['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='General Dynamics')
BA_L['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='BAE Systems')
INTC['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Intel', linestyle='--')
MSFT['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Microsoft', linestyle='--')
#IBM['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='IBM')
TSLA['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Tesla', linestyle='--')
XLNX['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Xilinx', linestyle='--')
AVGO['Returns'].loc[russia_china_start:russia_china_end].plot(kind='kde', label='Broadcom', linestyle='--')

plt.legend()
plt.xlim([-0.15, 0.15])
plt.ylabel('Density', fontweight='bold')
plt.yticks(fontweight='bold')
plt.xticks(fontweight='bold')
plt.suptitle('Russia/China Tension - Oct 2021-present', y=0.95, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig23.png', bbox_inches='tight', format="png", dpi=600)

# %%
stocktempE = stock_data_E.corr()

plt.imshow(stocktempE, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_E)), stock_corr_E.columns, rotation = 90,fontweight='bold');
plt.yticks(range(len(stock_corr_E)), stock_corr_E.columns,fontweight='bold');
plt.suptitle('Russia/China Tension - Oct 2021-present', y=0.97, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig24.png', bbox_inches='tight', format="png", dpi=600)

# %%
stocktempD = stock_data_D.corr()

plt.imshow(stocktempD, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_D)), stock_corr_D.columns, rotation = 90,fontweight='bold');
plt.yticks(range(len(stock_corr_D)), stock_corr_D.columns,fontweight='bold');
plt.suptitle('Invasion of Iraq - 2002-09', y=0.97, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig25.png', bbox_inches='tight', format="png", dpi=600)

# %%
stocktempC = stock_data_C.corr()

plt.imshow(stocktempC, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_C)), stock_corr_C.columns, rotation = 90,fontweight='bold');
plt.yticks(range(len(stock_corr_C)), stock_corr_C.columns,fontweight='bold');
plt.suptitle('Invasion of Afghanistan - 2001-14', y=0.97, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig26.png', bbox_inches='tight', format="png", dpi=600)

# %%
stocktempB = stock_data_B.corr()

plt.imshow(stocktempB, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_B)), stock_corr_B.columns, rotation = 90,fontweight='bold');
plt.yticks(range(len(stock_corr_B)), stock_corr_B.columns,fontweight='bold');
plt.suptitle('Operation Desert Storm - 1990-91', y=0.97, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig27.png', bbox_inches='tight', format="png", dpi=600)

# %%
stocktempA = stock_data_A.corr()

plt.imshow(stocktempA, cmap = 'hot', interpolation = 'none');
plt.colorbar()
plt.xticks(range(len(stock_corr_A)), stock_corr_A.columns, rotation = 90,fontweight='bold');
plt.yticks(range(len(stock_corr_A)), stock_corr_A.columns,fontweight='bold');
plt.suptitle('Fall of Communism 1989-90', y=0.97, size='x-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig28.png', bbox_inches='tight', format="png", dpi=600)

# %%
stock_data_C.tail()
# Out:
#                    LMT         NOC        RTX          GD        BA_L  \
# Date
# 2014-12-19  159.570541  133.636398  61.359440  119.210854  337.018738
# 2014-12-22  162.549316  135.722534  62.182240  120.549332  343.282776
# 2014-12-23  161.986664  134.902344  62.219372  120.472641  344.739471
# 2014-12-24  162.532730  135.294586  62.060139  120.668686  345.322235
# 2014-12-26  162.872025  135.107361  62.235291  120.540802         NaN
#
#                   LHX          BA        HON     AIR_DE       INTC       MSFT  \
# Date
# 2014-12-19  63.648716  110.403633  83.569435  36.882648  30.086409  41.986717
# 2014-12-22  64.382607  112.144127  83.610748  36.781197  30.781279  42.268608
# 2014-12-23  64.277771  113.727188  84.246857  36.754738  30.963274  42.682663
# 2014-12-24  64.295235  114.785500  84.230347        NaN  30.971540  42.409561
# 2014-12-26  64.461250  115.126602  83.957703        NaN  31.062532  42.180519
#
#                    Gold  Bonds        Oil       S&P500
# Date
# 2014-12-19  1195.900024  2.176  56.520000  2070.649902
# 2014-12-22  1179.699951  2.162  55.259998  2078.540039
# 2014-12-23  1177.900024  2.257  57.119999  2082.169922
# 2014-12-24  1173.500000  2.264  55.840000  2081.879883
# 2014-12-26  1195.300049  2.250  54.730000  2088.770020

# %%
plt.figure(figsize=(13,8))
colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stock_corr_A, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stock_corr_B)+5), 'weight': 'bold'})
plt.xticks(np.arange(len(stock_corr_A))+0.5, stock_corr_A.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_A))+0.5, stock_corr_A.columns, fontweight='bold');
plt.suptitle('Fall of Communism 1989-90', y=0.95, size='xx-large', fontweight = 'bold');
plt.savefig(save_results_to + 'Fig29.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
sns.set_style('whitegrid')

mask = np.zeros_like(stocktempA, dtype=bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stocktempA, mask=mask, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stocktempA)), 'weight': 'bold'}, \
            cbar_kws={"shrink": .75}, fmt=".2f")

plt.xticks(np.arange(len(stock_corr_A))+0.5, stock_corr_A.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_A))+0.5, stock_corr_A.columns, rotation = 0, fontweight='bold');
plt.suptitle('Fall of Communism 1989-90', x=0.55, y=0.93, size='xx-large', fontweight = 'bold');
plt.savefig(save_results_to + 'Fig30.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stock_corr_B, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stock_corr_B)+5), 'weight': 'bold'})

plt.xticks(np.arange(len(stock_corr_B))+0.5, stock_corr_B.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_B))+0.5, stock_corr_B.columns, fontweight='bold');
plt.suptitle('Operation Desert Storm - 1990-91', y=0.95, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig31.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
sns.set_style('whitegrid')

mask = np.zeros_like(stocktempB, dtype=bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stocktempB, mask=mask, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stocktempB)), 'weight': 'bold'}, \
            cbar_kws={"shrink": .75}, fmt=".2f")

plt.xticks(np.arange(len(stock_corr_B))+0.5, stock_corr_B.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_B))+0.5, stock_corr_B.columns, fontweight='bold');
plt.suptitle('Operation Desert Storm - 1990-91', x=0.55, y=0.93, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig32.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
colourmap = sns.diverging_palette(255, 195, s=90, l=55, center="dark", as_cmap=True)
sns.heatmap(stock_corr_C, annot=True,cmap=colourmap,linewidth=2, linecolor='w', square=True)

plt.xticks(np.arange(len(stock_corr_C))+0.5, stock_corr_C.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_C))+0.5, stock_corr_C.columns, fontweight='bold');
plt.suptitle('Invasion of Afghanistan - 2001-14', y=0.95, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig33.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
sns.set_style('whitegrid')

mask = np.zeros_like(stocktempE, dtype=bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stocktempC, mask=mask, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stocktempC)), 'weight': 'bold'}, \
            cbar_kws={"shrink": .75}, fmt=".2f")

plt.xticks(np.arange(len(stock_corr_C))+0.5, stock_corr_C.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_C))+0.5, stock_corr_C.columns, fontweight='bold');
plt.suptitle('Invasion of Afghanistan - 2001-14', x=0.55, y=0.93, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig34.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
colourmap = sns.diverging_palette(255, 10, s=90, l=55, center="dark", as_cmap=True)
sns.heatmap(stock_corr_D, annot=True,cmap=colourmap,linewidth=2, linecolor='w', square=True)

plt.xticks(np.arange(len(stock_corr_D))+0.5, stock_corr_D.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_D))+0.5, stock_corr_D.columns, rotation = 0, fontweight='bold');
plt.suptitle('Invasion of Iraq - 2002-09', y=0.95, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig35.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
sns.set_style('whitegrid')

mask = np.zeros_like(stocktempE, dtype=bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stocktempD, mask=mask, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stocktempD)), 'weight': 'bold'}, \
            cbar_kws={"shrink": .75}, fmt=".2f")

plt.xticks(np.arange(len(stock_corr_D))+0.5, stock_corr_D.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_D))+0.5, stock_corr_D.columns, rotation = 0, fontweight='bold');
plt.suptitle('Invasion of Iraq - 2002-09', x=0.55, y=0.93, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig36.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
colourmap = sns.diverging_palette(255, 10, s=90, l=55, center="dark", as_cmap=True)
sns.heatmap(stock_corr_E, annot=True,cmap=colourmap,linewidth=2, linecolor='w', square=True)

plt.xticks(np.arange(len(stock_corr_E))+0.5, stock_corr_E.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_E))+0.5, stock_corr_E.columns, rotation = 0,fontweight='bold');
plt.suptitle('Russia/China Tension - Oct 2021-present', y=0.95, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig37.png', bbox_inches='tight', format="png", dpi=600)

# %%
plt.figure(figsize=(13,8))
sns.set_style('whitegrid')

mask = np.zeros_like(stocktempE, dtype=bool)
mask[np.triu_indices_from(mask)] = True
mask[np.diag_indices_from(mask)] = False

colourmap = sns.diverging_palette(255, 195, s=95, l=55, center="dark", as_cmap=True)
sns.heatmap(stocktempE, mask=mask, vmin=-1, vmax=1, center=0.00, annot=True,cmap=colourmap,\
            linewidth=2, linecolor='w', square=True, \
            annot_kws={'size': 35 / np.sqrt(len(stocktempE)), 'weight': 'bold'}, \
            cbar_kws={"shrink": .75}, fmt=".2f")

plt.xticks(np.arange(len(stock_corr_E))+0.5, stock_corr_E.columns, rotation = 90, fontweight='bold');
plt.yticks(np.arange(len(stock_corr_E))+0.5, stock_corr_E.columns, rotation = 0,fontweight='bold');
plt.suptitle('Russia/China Tension - Oct 2021-present', x=0.55, y=0.93, size='xx-large',fontweight='bold');
plt.savefig(save_results_to + 'Fig38.png', bbox_inches='tight', format="png", dpi=600)

#255, 195, s=95, l=55
#255, 10, s=90, l=55
#255, 195, s=90, l=55
